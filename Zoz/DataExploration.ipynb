# %%
#adding a comment for github testing
import pandas as pd
directory = 'C:\\Users\\zoebe\\PycharmProjects\\DUAssignments\\Stats_2\\Stats2\\DASS_data_21.02.19\\'
very_sad = pd.read_csv(f'{directory}data.csv', delimiter='	')
display(very_sad.head())

"""IRT (Item Response Theory) 
Clustering: LCA
Decision Tree?
Hierarchical Linear Models
"""

print(very_sad.columns.unique().tolist())
# Out:
#    Q1A  Q1I   Q1E  Q2A  Q2I   Q2E  Q3A  Q3I   Q3E  Q4A  ...  screensize  \
# 0    4   28  3890    4   25  2122    2   16  1944    4  ...           1
# 1    4    2  8118    1   36  2890    2   35  4777    3  ...           2
# 2    3    7  5784    1   33  4373    4   41  3242    1  ...           2
# 3    2   23  5081    3   11  6837    2   37  5521    1  ...           2
# 4    2   36  3215    2   13  7731    3    5  4156    4  ...           2
#
#    uniquenetworklocation  hand  religion  orientation  race  voted  married  \
# 0                      1     1        12            1    10      2        1
# 1                      1     2         7            0    70      2        1
# 2                      1     1         4            3    60      1        1
# 3                      1     2         4            5    70      2        1
# 4                      2     3        10            1    10      2        1
#
#    familysize       major
# 0           2         NaN
# ...

# %%
numq = 42
df = very_sad[[f'Q{i}A' for i in range(1, numq+1)] + ['gender']]
display(df)

df.to_csv(f'q1Throughq{numq}andGender.csv')

numq = 6

df2 = very_sad[[f'Q{i}A' for i in range(1, numq+1)] + ['gender']]
df2.to_csv(f'q1Throughq{numq}andGender.csv')
# Out:
#        Q1A  Q2A  Q3A  Q4A  Q5A  Q6A  Q7A  Q8A  Q9A  Q10A  ...  Q34A  Q35A  \
# 0        4    4    2    4    4    4    4    4    2     1  ...     3     4
# 1        4    1    2    3    4    4    3    4    3     2  ...     2     2
# 2        3    1    4    1    4    3    1    3    2     4  ...     4     3
# 3        2    3    2    1    3    3    4    2    3     3  ...     4     1
# 4        2    2    3    4    4    2    4    4    4     3  ...     4     3
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...   ...  ...   ...   ...
# 39770    2    1    3    2    3    2    1    3    1     4  ...     4     1
# 39771    3    4    3    4    3    4    4    4    3     4  ...     4     3
# 39772    2    1    2    1    1    1    1    1    2     1  ...     1     1
# 39773    3    1    2    2    3    3    3    4    3     1  ...     2     3
# 39774    2    1    2    1    4    2    1    1    1     1  ...     3     2
#
#        Q36A  Q37A  Q38A  Q39A  Q40A  Q41A  Q42A  gender
# ...
