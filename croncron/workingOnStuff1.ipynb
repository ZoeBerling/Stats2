# %%
import pandas as pd
df = pd.read_csv('data.csv', delimiter = '	')

df.to_csv('aData.csv', index=False)
df2 = pd.read_csv('aData.csv')

display(df2.head(5))
display(df.head(10))
myColumns = list(df.columns)
print(myColumns)
# Out:
#    Q1A  Q1I   Q1E  Q2A  Q2I   Q2E  Q3A  Q3I   Q3E  Q4A  ...  screensize  \
# 0    4   28  3890    4   25  2122    2   16  1944    4  ...           1
# 1    4    2  8118    1   36  2890    2   35  4777    3  ...           2
# 2    3    7  5784    1   33  4373    4   41  3242    1  ...           2
# 3    2   23  5081    3   11  6837    2   37  5521    1  ...           2
# 4    2   36  3215    2   13  7731    3    5  4156    4  ...           2
#
#    uniquenetworklocation  hand  religion  orientation  race  voted  married  \
# 0                      1     1        12            1    10      2        1
# 1                      1     2         7            0    70      2        1
# 2                      1     1         4            3    60      1        1
# 3                      1     2         4            5    70      2        1
# 4                      2     3        10            1    10      2        1
#
#    familysize       major
# 0           2         NaN
# ...

# %%
for i in myColumns:
    print(i, ': ', df[i].unique())
# Out:
# Q1A :  [4 3 2 1]
# Q1I :  [28  2  7 23 36 18 20 34  4 38 37 35 10 17 15  5  8  1 41 14 12  9 25 27
#  39 11 42 21  3 40 32 22 24 16  6 33 19 13 30 29 26 31]
# Q1E :  [ 3890  8118  5784 ... 14275 28897 32251]
# Q2A :  [4 1 3 2]
# Q2I :  [25 36 33 11 13 28 34  9 14 16 35 24 20  1 18  3 27  4 38  6 39 10 22 26
#  42 17 15  8 19 40 29 21 41  5  7 32 37 31 30  2 12 23]
# Q2E :  [ 2122  2890  4373 ... 16945  6056  4555]
# Q3A :  [2 4 3 1]
# Q3I :  [16 35 41 37  5  2 38 39  1  9 28 18 30 26 22 11 25 20 31 21  8 15  7 13
#  40 10 34 17  3 14 36 12 32  6 24 29 27 23 42 19  4 33]
# Q3E :  [ 1944  4777  3242 ...  7216 10521 11734]
# Q4A :  [4 3 1 2]
# Q4I :  [ 8 28 13 27 10 40 12 20  7 34 15 35  3 16  2 42 32 17  5 21 38 18 11 37
#  14  1 31 19 26 39 24 36 30 41  4 22  6  9 23 29 33 25]
# Q4E :  [ 2044  3090  6470 ...  9142 12680 16706]
# Q5A :  [4 3 1 2]
# Q5I :  [34 10 11 28  2 40 22  4  3 41 23 17 12 38 35  6 15 29  7  9 42  8 39 20
#  27 33 32 24 25 21 18 31 19  1  5 36 30 26 14 16 13 37]
# ...

# %%
df = pd.read_csv('data.csv', delimiter = '	')
df2 = df[['Q1A', 'Q2A', 'Q3A', 'Q4A', 'Q5A', 'Q6A']]
display(df2.head(5))
df2.to_csv('sampleData.csv', index=False)
# df2 = pd.read_csv('aData.csv')
# Out:
#    Q1A  Q2A  Q3A  Q4A  Q5A  Q6A
# 0    4    4    2    4    4    4
# 1    4    1    2    3    4    4
# 2    3    1    4    1    4    3
# 3    2    3    2    1    3    3
# 4    2    2    3    4    4    2
